# %% [markdown]
# #### Exploratory Data Analysis
# - A look into the dataset with pandas
# - Understanding columns
# - Filtering out the unnecessary columns
# - Categorical values check
# - Missing value check
# - Numerical values check
# - Outliers check
# - Explore distribution of binary columns

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
disease_data = pd.read_excel('Weekly2022.xlsx')
disease_data
# Out:
#     Organisation unit / Data  033B-CD01a. Malaria (diagnosed) - Cases  \
# 0                       Abim                                   1014.0
# 1                   Adjumani                                   3613.0
# 2                      Agago                                   1958.0
# 3                   Alebtong                                    729.0
# 4                   Amolatar                                   1384.0
# ..                       ...                                      ...
# 142                   Tororo                                   4219.0
# 143                   Wakiso                                   3208.0
# 144                    Yumbe                                   6818.0
# 145                    Zombo                                    990.0
# 146                      NaN                                      NaN
#
#      033B-CD01b. Malaria (diagnosed) - Deaths  033B-CD02a. Dysentery - Cases  \
# ...

# %%
disease_data = pd.read_excel('Weekly2022.xlsx', index_col=0) 
# Districts will serve as the index column
disease_data
# Out:
#                           033B-CD01a. Malaria (diagnosed) - Cases  \
# Organisation unit / Data
# Abim                                                       1014.0
# Adjumani                                                   3613.0
# Agago                                                      1958.0
# Alebtong                                                    729.0
# Amolatar                                                   1384.0
# ...                                                           ...
# Tororo                                                     4219.0
# Wakiso                                                     3208.0
# Yumbe                                                      6818.0
# Zombo                                                       990.0
# NaN                                                           NaN
#
#                           033B-CD01b. Malaria (diagnosed) - Deaths  \
# Organisation unit / Data
# ...

# %%
disease_data.describe(include='all')
# Out:
#         033B-CD01a. Malaria (diagnosed) - Cases  \
# count                                146.000000
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                1388.294521
# std                                 1248.667710
# min                                   49.000000
# 25%                                  554.750000
# 50%                                 1024.000000
# 75%                                 1842.500000
# max                                 6818.000000
#
#         033B-CD01b. Malaria (diagnosed) - Deaths  \
# count                                   22.00000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    20.00000
# std                                     42.50042
# ...

# %%
disease_data.columns.tolist() # To filter the disease 'cases and deaths' only
# Out:
# ['033B-CD01a. Malaria (diagnosed) - Cases',
#  '033B-CD01b. Malaria (diagnosed) - Deaths',
#  '033B-CD02a. Dysentery - Cases',
#  '033B-CD02b. Dysentery - Deaths',
#  '033B-CD03a. SARI - Cases',
#  '033B-CD03b. SARI- Deaths',
#  '033B-CD04a. Acute Flaccid Paralysis - Cases',
#  '033B-CD04b. Acute Flaccid Paralysis- Deaths',
#  '033B-CD05a. AEFI - Cases',
#  '033B-CD05b. AEFI- Deaths',
#  '033B-CD06a. Animal bites(Suspected rabies) - Cases',
#  '033B-CD06b. Animal bites(Suspected rabies) - Deaths',
#  '033B-CD07a. Bacterial Meningitis - Cases',
#  '033B-CD07b. Bacterial Meningitis - Deaths',
#  '033B-CD08a. Cholera - Cases',
 '033B-TE06a. Human influenza due to a new subtype - Cases',
 '033B-TE06b. Human influenza due to a new subtype - Deaths',
 '033B-TE07a. Severe Acute Respiratory Syndrome (SARS) - Cases',
 '033B-TE07b. Severe Acute Respiratory Syndrome (SARS) - Deaths',
 '033B-TE08a. Smallpox - Cases',
 '033B-TE08b. Smallpox - Deaths']]

disease_data_subset
# Out:
#                           033B-CD01a. Malaria (diagnosed) - Cases  \
# Organisation unit / Data
# Abim                                                       1014.0
# Adjumani                                                   3613.0
# Agago                                                      1958.0
# Alebtong                                                    729.0
# Amolatar                                                   1384.0
# ...                                                           ...
# Tororo                                                     4219.0
# Wakiso                                                     3208.0
# Yumbe                                                      6818.0
# Zombo                                                       990.0
# NaN                                                           NaN
#
#                           033B-CD01b. Malaria (diagnosed) - Deaths  \
# Organisation unit / Data
# ...

# %%
disease_data_subset.dtypes # No need for data conversions since all are floats
# Out:
# 033B-CD01a. Malaria (diagnosed) - Cases                          float64
# 033B-CD01b. Malaria (diagnosed) - Deaths                         float64
# 033B-CD02a. Dysentery - Cases                                    float64
# 033B-CD02b. Dysentery - Deaths                                   float64
# 033B-CD03a. SARI - Cases                                         float64
#                                                                   ...
# 033B-TE06b. Human influenza due to a new subtype - Deaths        float64
# 033B-TE07a. Severe Acute Respiratory Syndrome (SARS) - Cases     float64
# 033B-TE07b. Severe Acute Respiratory Syndrome (SARS) - Deaths    float64
# 033B-TE08a. Smallpox - Cases                                     float64
# 033B-TE08b. Smallpox - Deaths                                    float64
# Length: 111, dtype: object

# %% [markdown]
# #### Malaria cases and Deaths(case study)

# %%
malaria = disease_data_subset[['033B-CD01a. Malaria (diagnosed) - Cases', '033B-CD01b. Malaria (diagnosed) - Deaths']]
malaria
# I choose malaria as a case study since it has almost complete data
# Out:
#                           033B-CD01a. Malaria (diagnosed) - Cases  \
# Organisation unit / Data
# Abim                                                       1014.0
# Adjumani                                                   3613.0
# Agago                                                      1958.0
# Alebtong                                                    729.0
# Amolatar                                                   1384.0
# ...                                                           ...
# Tororo                                                     4219.0
# Wakiso                                                     3208.0
# Yumbe                                                      6818.0
# Zombo                                                       990.0
# NaN                                                           NaN
#
#                           033B-CD01b. Malaria (diagnosed) - Deaths
# Organisation unit / Data
# ...

# %%
malaria[['033B-CD01a. Malaria (diagnosed) - Cases', '033B-CD01b. Malaria (diagnosed) - Deaths']].plot(kind='scatter', 
        x='033B-CD01a. Malaria (diagnosed) - Cases', y='033B-CD01b. Malaria (diagnosed) - Deaths', figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='033B-CD01a. Malaria (diagnosed) - Cases', ylabel='033B-CD01b. Malaria (diagnosed) - Deaths'>

# %%
malaria.isna().sum()
# Out:
# 033B-CD01a. Malaria (diagnosed) - Cases       1
# 033B-CD01b. Malaria (diagnosed) - Deaths    125
# dtype: int64
